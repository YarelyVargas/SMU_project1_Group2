# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import linregress
import seaborn as sns

file = pd.read_csv("Data/UK_cars/toyota.csv")

file.head()
# Out:
#    model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
# 1   GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0
# 2   GT86  2015  13998       Manual    27469   Petrol  265  36.2         2.0
# 3   GT86  2017  18998       Manual    14736   Petrol  150  36.2         2.0
# 4   GT86  2017  17498       Manual    36284   Petrol  145  36.2         2.0

# %%
file["model"] = [x.strip() for x in file.model]

# %%
mask = (file["model"] == "Aygo")|(file["model"] == "Yaris")
df2 = file.loc[mask,:]
df2
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 813   Yaris  2019  14000    Automatic     6821   Petrol  150  47.9         1.5
# 814   Yaris  2018  10750       Manual    14000   Petrol  145  58.9         1.5
# 815   Yaris  2016  11500    Automatic    31911   Hybrid    0  78.0         1.5
# 816   Yaris  2014   8500    Automatic    72053   Hybrid    0  76.3         1.5
# 817   Yaris  2017   8750       Manual    32594   Petrol  150  58.9         1.5
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 5603   Aygo  2017   9595    Automatic     7618    Other  145  67.3         1.0
# 5604   Aygo  2019   9694       Manual      100   Petrol  145  56.5         1.0
# 5605   Aygo  2018   9095    Automatic     7077    Other  145  67.0         1.0
# 5606   Aygo  2017   8690       Manual     2908   Petrol    0  68.9         1.0
# 5607   Aygo  2016   6275       Manual    43491    Other    0  69.0         1.0
#
# [4083 rows x 9 columns]

# %%
df2.groupby("model").agg({"price":"mean"})
# Out:
#               price
# model
# Aygo    7905.414584
# Yaris  10553.083883

# %%
df2.groupby("model").agg({"price":"median"})
# Out:
#          price
# model
# Aygo    7895.0
# Yaris  10652.5

# %%
df2.groupby("model").agg({"price":"var"})
# Out:
#               price
# model
# Aygo   2.764884e+06
# Yaris  6.608439e+06

# %%
df2.groupby("model").agg({"price":"std"})
# Out:
#              price
# model
# Aygo   1662.794122
# Yaris  2570.688483

# %%
sns.histplot(data=df2, x="price")
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
df2.boxplot(by ='model', column =["price"], grid = True, rot = 90)
# Out:
# <AxesSubplot:title={'center':'price'}, xlabel='model'>

# %%
maska = (df2["price"] < 25000) 
df3 = df2.loc[maska,:]
df3
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 813   Yaris  2019  14000    Automatic     6821   Petrol  150  47.9         1.5
# 814   Yaris  2018  10750       Manual    14000   Petrol  145  58.9         1.5
# 815   Yaris  2016  11500    Automatic    31911   Hybrid    0  78.0         1.5
# 816   Yaris  2014   8500    Automatic    72053   Hybrid    0  76.3         1.5
# 817   Yaris  2017   8750       Manual    32594   Petrol  150  58.9         1.5
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 5603   Aygo  2017   9595    Automatic     7618    Other  145  67.3         1.0
# 5604   Aygo  2019   9694       Manual      100   Petrol  145  56.5         1.0
# 5605   Aygo  2018   9095    Automatic     7077    Other  145  67.0         1.0
# 5606   Aygo  2017   8690       Manual     2908   Petrol    0  68.9         1.0
# 5607   Aygo  2016   6275       Manual    43491    Other    0  69.0         1.0
#
# [4082 rows x 9 columns]

# %%
df3.boxplot(by ='model', column =["price"], grid = True, rot = 90)
# Out:
# <AxesSubplot:title={'center':'price'}, xlabel='model'>

# %%
sns.histplot(data=df3, x="price")
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
df3.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 813  Yaris  2019  14000    Automatic     6821   Petrol  150  47.9         1.5
# 814  Yaris  2018  10750       Manual    14000   Petrol  145  58.9         1.5
# 815  Yaris  2016  11500    Automatic    31911   Hybrid    0  78.0         1.5
# 816  Yaris  2014   8500    Automatic    72053   Hybrid    0  76.3         1.5
# 817  Yaris  2017   8750       Manual    32594   Petrol  150  58.9         1.5

# %%
import warnings
warnings.filterwarnings('ignore')

from matplotlib import pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
population1a = df3.loc[df3["model"]=="Yaris",:]
population2a= df3.loc[df3["model"]=="Aygo",:]
population1b = population1a["price"]
population2b = population2a["price"]

plt.scatter(range(len(population1b)), population1b, label="Yaris")
plt.scatter(range(len(population2b)), population2b, label="Aygo")
plt.legend()
plt.show()

plt.hist(population1b, 10, density=True, alpha=0.7, label="Yaris")
plt.hist(population2b, 10, density=True, alpha=0.7, label="Aygo")
plt.axvline(population1b.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(population2b.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()  
plt.show()

# %%
np.mean(population1b)
# Out:
# 10545.803394625176

# %%
np.mean(population2b)
# Out:
# 7905.414584395717

# %%
np.var(population1b)
# Out:
# 6495961.578036574

# %%
np.var(population2b)
# Out:
# 2763474.3559117196

# %%
stats.ttest_ind(population1b, population2b, equal_var=False)
# Out:
# Ttest_indResult(statistic=39.474492802499356, pvalue=1.8625242244512783e-284)

# %%
file2 = pd.read_csv("Data/UK_cars/ford.csv")

file2.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
file2["model"] = [x.strip() for x in file2.model]

# %%
maskb = (file2["model"] == "Fiesta")|(file2["model"] == "Focus")
df2b = file2.loc[maskb,:]
df2b
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 0      Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7
# 1       Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 2       Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 3      Fiesta  2019  17500       Manual    10460   Petrol  145  40.3
# 4      Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7
# ...       ...   ...    ...          ...      ...      ...  ...   ...
# 17952  Fiesta  2017   9899    Automatic    16303   Petrol    0  57.7
# 17954   Focus  2016  16000       Manual    19834   Petrol  200  41.5
# 17955  Fiesta  2018  12500    Automatic     7047   Petrol  145  48.7
# 17960  Fiesta  2016   7999       Manual    31348   Petrol  125  54.3
# 17963   Focus  2015   9999       Manual     7010   Diesel   20  67.3
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...           ...
# 17952         1.0
# 17954         2.0
# 17955         1.0
# 17960         1.2
# 17963         1.6
#
# [11145 rows x 9 columns]

# %%
df2b.groupby("model").agg({"price":"mean"})
# Out:
#                price
# model
# Fiesta  10196.298002
# Focus   13185.882956

# %%
sns.histplot(data=df2b, x="price")
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
df2b.boxplot(by ='model', column =["price"], grid = True, rot = 90)
# Out:
# <AxesSubplot:title={'center':'price'}, xlabel='model'>

# %%
maske = (df2b["price"] < 35000) 
df3b = df2b.loc[maske,:]
df3b
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 0      Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7
# 1       Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 2       Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 3      Fiesta  2019  17500       Manual    10460   Petrol  145  40.3
# 4      Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7
# ...       ...   ...    ...          ...      ...      ...  ...   ...
# 17952  Fiesta  2017   9899    Automatic    16303   Petrol    0  57.7
# 17954   Focus  2016  16000       Manual    19834   Petrol  200  41.5
# 17955  Fiesta  2018  12500    Automatic     7047   Petrol  145  48.7
# 17960  Fiesta  2016   7999       Manual    31348   Petrol  125  54.3
# 17963   Focus  2015   9999       Manual     7010   Diesel   20  67.3
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...           ...
# 17952         1.0
# 17954         2.0
# 17955         1.0
# 17960         1.2
# 17963         1.6
#
# [11143 rows x 9 columns]

# %%
df3b.boxplot(by ='model', column =["price"], grid = True, rot = 90)
# Out:
# <AxesSubplot:title={'center':'price'}, xlabel='model'>

# %%
sns.histplot(data=df3b, x="price")
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
maskh = (((df3b["model"] == "Fiesta") & (df3b["price"] < 20000)) | ((df3b["model"] == "Focus") & (df3b["price"] < 27000)))
df3c = df3b.loc[maskh,:]
df3c
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 0      Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7
# 1       Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 2       Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 3      Fiesta  2019  17500       Manual    10460   Petrol  145  40.3
# 4      Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7
# ...       ...   ...    ...          ...      ...      ...  ...   ...
# 17952  Fiesta  2017   9899    Automatic    16303   Petrol    0  57.7
# 17954   Focus  2016  16000       Manual    19834   Petrol  200  41.5
# 17955  Fiesta  2018  12500    Automatic     7047   Petrol  145  48.7
# 17960  Fiesta  2016   7999       Manual    31348   Petrol  125  54.3
# 17963   Focus  2015   9999       Manual     7010   Diesel   20  67.3
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...           ...
# 17952         1.0
# 17954         2.0
# 17955         1.0
# 17960         1.2
# 17963         1.6
#
# [11100 rows x 9 columns]

# %%
df3c.boxplot(by ='model', column =["price"], grid = True, rot = 90)
# Out:
# <AxesSubplot:title={'center':'price'}, xlabel='model'>

# %%
sns.histplot(data=df3c, x="price")
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
population1c =  df3c.loc[df3c["model"]=="Fiesta",:]
population2c= df3c.loc[df3c["model"]=="Focus",:]
population1d = population1c["price"]
population2d = population2c["price"]

plt.scatter(range(len(population1d)), population1d, label="Fiesta")
plt.scatter(range(len(population2d)), population2d, label="Focus")
plt.legend()
plt.show()

plt.hist(population1d, 10, density=True, alpha=0.7, label="Fiesta")
plt.hist(population2d, 10, density=True, alpha=0.7, label="Focus")
plt.axvline(population1b.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(population2b.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()  
plt.show()

# %%
np.mean(population1d)
# Out:
# 10165.540366972476

# %%
np.mean(population2d)
# Out:
# 13083.716885964912

# %%
np.var(population1d)
# Out:
# 7997103.740113615

# %%
np.var(population2d)
# Out:
# 18576801.28234644

# %%
stats.ttest_ind(population1d, population2d, equal_var=False)
# Out:
# Ttest_indResult(statistic=-40.09278905193241, pvalue=0.0)

# %%
Toyota = df3
Ford = df3c
list_of_dataframes = [Toyota, Ford]

# %%
df_cars = pd.concat(list_of_dataframes, ignore_index=True)
df_cars
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       Yaris  2019  14000    Automatic     6821   Petrol  150  47.9
# 1       Yaris  2018  10750       Manual    14000   Petrol  145  58.9
# 2       Yaris  2016  11500    Automatic    31911   Hybrid    0  78.0
# 3       Yaris  2014   8500    Automatic    72053   Hybrid    0  76.3
# 4       Yaris  2017   8750       Manual    32594   Petrol  150  58.9
# ...       ...   ...    ...          ...      ...      ...  ...   ...
# 15177  Fiesta  2017   9899    Automatic    16303   Petrol    0  57.7
# 15178   Focus  2016  16000       Manual    19834   Petrol  200  41.5
# 15179  Fiesta  2018  12500    Automatic     7047   Petrol  145  48.7
# 15180  Fiesta  2016   7999       Manual    31348   Petrol  125  54.3
# 15181   Focus  2015   9999       Manual     7010   Diesel   20  67.3
#
#        engineSize
# 0             1.5
# 1             1.5
# 2             1.5
# 3             1.5
# 4             1.5
# ...           ...
# 15177         1.0
# 15178         2.0
# 15179         1.0
# 15180         1.2
# 15181         1.6
#
# [15182 rows x 9 columns]

# %%
#https://towardsdatascience.com/anova-test-with-python-cfbf4013328b
# import matplotlib.pyplot as plt
# %matplotlib inline
# import seaborn as sns
sns.displot(df_cars,x='price',hue='model',kind='kde',height=5,aspect=2)
sns.displot(df_cars,x='price',hue='model',multiple='dodge',height=5,aspect=2)

# %%
models = df_cars['model'].unique()
for model in models:
    stats.probplot(df_cars[df_cars['model'] == model]['price'], dist="norm", plot=plt)
    plt.title("Probability Plot - " +  model)
    plt.show()

# %%
ratio = df_cars.groupby('model').std().max() / df_cars.groupby('model').std().min()
ratio
# Out:
# year           1.286459
# price          2.592356
# mileage        1.457784
# tax            1.104532
# mpg            2.274465
# engineSize    10.014912
# dtype: float64

# %%
# Create ANOVA backbone table
data = [['Between Groups', '', '', '', '', '', ''], ['Within Groups', '', '', '', '', '', ''], ['Total', '', '', '', '', '', '']] 
anova_table = pd.DataFrame(data, columns = ['Source of Variation', 'SS', 'df', 'MS', 'F', 'P-value', 'F crit']) 
anova_table.set_index('Source of Variation', inplace = True)

# calculate SSTR and update anova table
x_bar = df_cars['price'].mean()
SSTR = df_cars.groupby('model').count() * (df_cars.groupby('model').mean() - x_bar)**2
anova_table['SS']['Between Groups'] = SSTR['price'].sum()

# calculate SSE and update anova table
SSE = (df_cars.groupby('model').count() - 1) * df_cars.groupby('model').std()**2
anova_table['SS']['Within Groups'] = SSE['price'].sum()

# calculate SSTR and update anova table
SSTR = SSTR['price'].sum() + SSE['price'].sum()
anova_table['SS']['Total'] = SSTR

# update degree of freedom
anova_table['df']['Between Groups'] = df_cars['model'].nunique() - 1
anova_table['df']['Within Groups'] = df_cars.shape[0] - df_cars['model'].nunique()
anova_table['df']['Total'] =df_cars.shape[0] - 1

# calculate MS
anova_table['MS'] = anova_table['SS'] / anova_table['df']

# calculate F 
F = anova_table['MS']['Between Groups'] / anova_table['MS']['Within Groups']
anova_table['F']['Between Groups'] = F

# p-value
anova_table['P-value']['Between Groups'] = 1 - stats.f.cdf(F, anova_table['df']['Between Groups'], anova_table['df']['Within Groups'])

# F critical 
alpha = 0.05
# possible types "right-tailed, left-tailed, two-tailed"
tail_hypothesis_type = "two-tailed"
if tail_hypothesis_type == "two-tailed":
    alpha /= 2
anova_table['F crit']['Between Groups'] = stats.f.ppf(1-alpha, anova_table['df']['Between Groups'], anova_table['df']['Within Groups'])

# Final ANOVA Table
anova_table
# Out:
#                                       SS     df                  MS  \
# Source of Variation
# Between Groups        42982035287.977989      3  14327345095.992662
# Within Groups        156208380026.801056  15178     10291763.079905
# Total                199190415314.779053  15181     13121033.878847
#
#                                F P-value    F crit
# Source of Variation
# Between Groups       1392.117656     0.0  3.116992
# Within Groups
# Total

# %%
# The p-value approach
print("Approach 1: The p-value approach to hypothesis testing in the decision rule")
conclusion = "Failed to reject the null hypothesis."
if anova_table['P-value']['Between Groups'] <= alpha:
    conclusion = "Null Hypothesis is rejected."
print("F-score is:", anova_table['F']['Between Groups'], " and p value is:", anova_table['P-value']['Between Groups'])    
print(conclusion)
# Out:
# Approach 1: The p-value approach to hypothesis testing in the decision rule
# F-score is: 1392.1176561056866  and p value is: 1.1102230246251565e-16
# Null Hypothesis is rejected.

# %%
df_cars.boxplot("price", by="model", figsize=(20, 10))
plt.show()

# %%
sns.violinplot(data=df_cars, x="model", y="price")
plt.show()

# %%
df_cars.groupby("model").agg({"price": ["mean", "std", "var", "count"]}, axis=1)
# Out:
#                price
#                 mean          std           var count
# model
# Aygo     7905.414584  1662.794122  2.764884e+06  1961
# Fiesta  10165.540367  2828.131313  7.998327e+06  6540
# Focus   13083.716886  4310.554029  1.858088e+07  4560
# Yaris   10545.803395  2549.318676  6.499026e+06  2121

# %%
group1 = df_cars[df_cars["model"] == "Aygo"]["price"]
group2 = df_cars[df_cars["model"] == "Fiesta"]["price"]
group3 = df_cars[df_cars["model"] == "Focus"]["price"]
group4 = df_cars[df_cars["model"] == "Yaris"]["price"]

# %%
stats.f_oneway(group1, group2, group3, group4)
# Out:
# F_onewayResult(statistic=1392.1176561056843, pvalue=0.0)

# %%
print(stats.ttest_ind(group1, group2, equal_var=False))
print(stats.ttest_ind(group1, group3, equal_var=True))
print(stats.ttest_ind(group1, group4, equal_var=False))

print(stats.ttest_ind(group2, group3, equal_var=False))
print(stats.ttest_ind(group2, group4, equal_var=True))

print(stats.ttest_ind(group3, group4, equal_var=False))
# Out:
# Ttest_indResult(statistic=-44.046727046413544, pvalue=0.0)
# Ttest_indResult(statistic=-51.57138560900871, pvalue=0.0)
# Ttest_indResult(statistic=-39.474492802499356, pvalue=1.8625242244512783e-284)
# Ttest_indResult(statistic=-40.09278905193241, pvalue=0.0)
# Ttest_indResult(statistic=-5.508856413435533, pvalue=3.715226414598675e-08)
# Ttest_indResult(statistic=30.037347629841285, pvalue=2.113110310686985e-185)

# %%
df_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15182 entries, 0 to 15181
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         15182 non-null  object
#  1   year          15182 non-null  int64
#  2   price         15182 non-null  int64
#  3   transmission  15182 non-null  object
#  4   mileage       15182 non-null  int64
#  5   fuelType      15182 non-null  object
#  6   tax           15182 non-null  int64
#  7   mpg           15182 non-null  float64
#  8   engineSize    15182 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 1.0+ MB

# %%
df_cars.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  15182.000000  15182.000000   15182.000000  15182.000000  15182.000000
# mean    2016.877289  10803.224213   21830.551904    100.573376     61.386688
# std        2.056196   3622.296768   17557.438461     65.586757      9.292117
# min     1998.000000    495.000000       1.000000      0.000000     26.300000
# 25%     2016.000000   8298.000000    9782.000000     20.000000     56.500000
# 50%     2017.000000  10298.000000   17250.000000    145.000000     60.100000
# 75%     2018.000000  12698.000000   29294.250000    145.000000     65.700000
# max     2060.000000  26995.000000  177644.000000    330.000000     88.300000
#
#          engineSize
# count  15182.000000
# mean       1.207575
# std        0.295449
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.500000
# max        2.500000

# %%
unique = df_cars["year"].unique()
unique
# Out:
# array([2019, 2018, 2016, 2014, 2017, 2020, 2013, 2015, 2009, 2007, 2008,
#        2002, 1999, 2012, 2011, 2010, 2005, 2000, 2003, 2006, 2004, 1998,
#        2060], dtype=int64)

# %%
maskb = df_cars["year"] == 2060
df_carsb = df_cars.loc[maskb,:]
df_carsb
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 15060  Fiesta  2060   6495    Automatic    54807   Petrol  205  42.8
#
#        engineSize
# 15060         1.4

# %%
maskc = df_cars["year"] != 2060
df_carsc = df_cars.loc[maskc,:]
df_carsc
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       Yaris  2019  14000    Automatic     6821   Petrol  150  47.9
# 1       Yaris  2018  10750       Manual    14000   Petrol  145  58.9
# 2       Yaris  2016  11500    Automatic    31911   Hybrid    0  78.0
# 3       Yaris  2014   8500    Automatic    72053   Hybrid    0  76.3
# 4       Yaris  2017   8750       Manual    32594   Petrol  150  58.9
# ...       ...   ...    ...          ...      ...      ...  ...   ...
# 15177  Fiesta  2017   9899    Automatic    16303   Petrol    0  57.7
# 15178   Focus  2016  16000       Manual    19834   Petrol  200  41.5
# 15179  Fiesta  2018  12500    Automatic     7047   Petrol  145  48.7
# 15180  Fiesta  2016   7999       Manual    31348   Petrol  125  54.3
# 15181   Focus  2015   9999       Manual     7010   Diesel   20  67.3
#
#        engineSize
# 0             1.5
# 1             1.5
# 2             1.5
# 3             1.5
# 4             1.5
# ...           ...
# 15177         1.0
# 15178         2.0
# 15179         1.0
# 15180         1.2
# 15181         1.6
#
# [15181 rows x 9 columns]

# %%
unique = df_carsc["year"].unique()
unique
# Out:
# array([2019, 2018, 2016, 2014, 2017, 2020, 2013, 2015, 2009, 2007, 2008,
#        2002, 1999, 2012, 2011, 2010, 2005, 2000, 2003, 2006, 2004, 1998],
#       dtype=int64)

# %%
sns.histplot(data=df_carsc, x="year")
# Out:
# <AxesSubplot:xlabel='year', ylabel='Count'>

# %%
count = df_carsc["year"].value_counts()
count
# Out:
# 2017    3967
# 2018    3562
# 2019    2744
# 2016    1913
# 2015    1178
# 2014     725
# 2013     514
# 2020     181
# 2012      96
# 2009      73
# 2011      70
# 2010      45
# 2008      43
# 2007      29
# 2005      13
# 2006      13
# 2004       4
# 2003       4
# 2002       3
# 2000       2
# 1999       1
# 1998       1
# Name: year, dtype: int64

# %%
maskd = ((df_carsc["year"] == 2017)|(df_carsc["year"] == 2018)|(df_carsc["year"] == 2019)|(df_carsc["year"] == 2016)|(df_carsc["year"] == 2015)|(df_carsc["year"] == 2014)|(df_carsc["year"] == 2013)|(df_carsc["year"] == 2020))
df_carsd = df_carsc.loc[maskd,:]
df_carsd
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       Yaris  2019  14000    Automatic     6821   Petrol  150  47.9
# 1       Yaris  2018  10750       Manual    14000   Petrol  145  58.9
# 2       Yaris  2016  11500    Automatic    31911   Hybrid    0  78.0
# 3       Yaris  2014   8500    Automatic    72053   Hybrid    0  76.3
# 4       Yaris  2017   8750       Manual    32594   Petrol  150  58.9
# ...       ...   ...    ...          ...      ...      ...  ...   ...
# 15177  Fiesta  2017   9899    Automatic    16303   Petrol    0  57.7
# 15178   Focus  2016  16000       Manual    19834   Petrol  200  41.5
# 15179  Fiesta  2018  12500    Automatic     7047   Petrol  145  48.7
# 15180  Fiesta  2016   7999       Manual    31348   Petrol  125  54.3
# 15181   Focus  2015   9999       Manual     7010   Diesel   20  67.3
#
#        engineSize
# 0             1.5
# 1             1.5
# 2             1.5
# 3             1.5
# 4             1.5
# ...           ...
# 15177         1.0
# 15178         2.0
# 15179         1.0
# 15180         1.2
# 15181         1.6
#
# [14784 rows x 9 columns]

# %%
count = df_carsd["year"].value_counts()
count
# Out:
# 2017    3967
# 2018    3562
# 2019    2744
# 2016    1913
# 2015    1178
# 2014     725
# 2013     514
# 2020     181
# Name: year, dtype: int64

# %%
sns.histplot(data=df_carsd, x="mileage")
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='Count'>

# %%
df_cars.boxplot("mileage", by="model", figsize=(20, 10))
plt.show()

# %%
mask2 = ((df_carsd["model"] == "Aygo") & (df_carsd["mileage"] < 75000)) 
df3 = df_carsd.loc[mask2,:]
#df3.reset_index(drop=True, inplace=True)
# df3.columns =[]
df3

mask3 = ((df_carsd["model"] == "Yaris") & (df_carsd["mileage"] < 75000)) 
df4 = df_carsd.loc[mask3,:]
#df4.reset_index(drop=True, inplace=True)
# df4.columns =[]
df4

mask4 = ((df_carsd["model"] == "Fiesta") & (df_carsd["mileage"] < 75000)) 
df5 = df_carsd.loc[mask4,:]
#df5.reset_index(drop=True, inplace=True)
# df5.columns =[]
df5

mask5 = ((df_carsd["model"] == "Focus") & (df_carsd["mileage"] < 75000)) 
df6 = df_carsd.loc[mask5,:]
#df6.reset_index(drop=True, inplace=True)
# df6.columns =[]
df6
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 4083   Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 4084   Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 4089   Focus  2018  10000       Manual    48141   Petrol  145  61.4
# 4098   Focus  2017  18499       Manual    13063   Petrol  145  41.5
# 4104   Focus  2019  18990       Manual     8400   Petrol  145  60.1
# ...      ...   ...    ...          ...      ...      ...  ...   ...
# 15166  Focus  2017  18500       Manual    10960   Petrol  145  41.5
# 15168  Focus  2017  11000       Manual    17339   Petrol  145  60.1
# 15173  Focus  2015   8000       Manual    65000   Diesel    0  74.3
# 15178  Focus  2016  16000       Manual    19834   Petrol  200  41.5
# 15181  Focus  2015   9999       Manual     7010   Diesel   20  67.3
#
#        engineSize
# 4083          1.0
# 4084          1.0
# 4089          1.0
# 4098          2.0
# 4104          1.0
# ...           ...
# 15166         2.0
# 15168         1.0
# 15173         1.5
# 15178         2.0
# 15181         1.6
#
# [4339 rows x 9 columns]

# %%
list_of_dataframes = [df3, df4, df5,df6]
dfb = pd.concat(list_of_dataframes)



dfb.boxplot(by ='model', column =["mileage"], grid = True)
# Out:
# <AxesSubplot:title={'center':'mileage'}, xlabel='model'>

# %%
sns.histplot(data=dfb, x="mileage")
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='Count'>

# %%
# Determine outliers using upper and lower bounds
import numpy as np
Q3a = np.quantile(df3["mileage"], 0.75)
Q1a = np.quantile(df3["mileage"], 0.25)
IQRa = Q3a-Q1a
lower_range_a = Q1a - 1.5 * IQRa
upper_range_a = Q3a + 1.5 * IQRa

Q3b = np.quantile(df4["mileage"], 0.75)
Q1b = np.quantile(df4["mileage"], 0.25)
IQRb = Q3b-Q1b
lower_range_b = Q1b - 1.5 * IQRb
upper_range_b = Q3b + 1.5 * IQRb

Q3c = np.quantile(df5["mileage"], 0.75)
Q1c = np.quantile(df5["mileage"], 0.25)
IQRc = Q3c-Q1c
lower_range_c = Q1c - 1.5 * IQRc
upper_range_c = Q3c + 1.5 * IQRc

Q3d = np.quantile(df6["mileage"], 0.75)
Q1d = np.quantile(df6["mileage"], 0.25)
IQRd = Q3d-Q1d
lower_range_d = Q1d - 1.5 * IQRd
upper_range_d = Q3d + 1.5 * IQRd


mask6 = ((df3["mileage"] < lower_range_a) | (df3["mileage"] > upper_range_a))
outliers_a = df3.loc[mask6,:]

outliers_a

mask7 = ((df4["mileage"] < lower_range_b) | (df4["mileage"] > upper_range_b))
outliers_b = df4.loc[mask7,:]

outliers_b

mask8 = ((df5["mileage"] < lower_range_c) | (df5["mileage"] > upper_range_c))
outliers_c = df5.loc[mask8,:]

outliers_c

mask9 = ((df6["mileage"] < lower_range_d) | (df6["mileage"] > upper_range_d))
outliers_d = df6.loc[mask9,:]

outliers_d.sort_values("mileage")
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 13081  Focus  2013   5995       Manual    58610   Petrol  145  47.9
# 5732   Focus  2016  13240    Automatic    58644   Diesel   30  61.4
# 14765  Focus  2015  11495       Manual    58655   Diesel   20  67.3
# 14675  Focus  2016   8750       Manual    58665   Diesel    0  74.3
# 5239   Focus  2016   8000       Manual    58774   Diesel    0  74.3
# ...      ...   ...    ...          ...      ...      ...  ...   ...
# 5637   Focus  2013   5971       Manual    73411   Diesel   20  67.3
# 7549   Focus  2015   7500       Manual    73831   Diesel    0  74.3
# 9707   Focus  2013   4995       Manual    74015   Diesel   20  67.3
# 13994  Focus  2015   7099       Manual    74176   Diesel    0  74.3
# 12135  Focus  2014   5710       Manual    74754   Diesel   20  67.3
#
#        engineSize
# 13081         1.6
# 5732          2.0
# 14765         2.0
# 14675         1.5
# 5239          1.5
# ...           ...
# 5637          1.6
# 7549          1.5
# 9707          1.6
# 13994         1.5
# 12135         1.6
#
# [154 rows x 9 columns]

# %%
mask2 = ((df_carsd["model"] == "Aygo") & (df_carsd["mileage"] < 48653)) 
df3 = df_carsd.loc[mask2,:]
#df3.reset_index(drop=True, inplace=True)
# df3.columns =[]
df3

mask3 = ((df_carsd["model"] == "Yaris") & (df_carsd["mileage"] < 56307)) 
df4 = df_carsd.loc[mask3,:]
#df4.reset_index(drop=True, inplace=True)
# df4.columns =[]
df4

mask4 = ((df_carsd["model"] == "Fiesta") & (df_carsd["mileage"] < 54927)) 
df5 = df_carsd.loc[mask4,:]
#df5.reset_index(drop=True, inplace=True)
# df5.columns =[]
df5

mask5 = ((df_carsd["model"] == "Focus") & (df_carsd["mileage"] < 58610)) 
df6 = df_carsd.loc[mask5,:]
#df6.reset_index(drop=True, inplace=True)
# df6.columns =[]
df6
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 4083   Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 4084   Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 4089   Focus  2018  10000       Manual    48141   Petrol  145  61.4
# 4098   Focus  2017  18499       Manual    13063   Petrol  145  41.5
# 4104   Focus  2019  18990       Manual     8400   Petrol  145  60.1
# ...      ...   ...    ...          ...      ...      ...  ...   ...
# 15164  Focus  2018  14000       Manual     8724   Diesel  145  74.3
# 15166  Focus  2017  18500       Manual    10960   Petrol  145  41.5
# 15168  Focus  2017  11000       Manual    17339   Petrol  145  60.1
# 15178  Focus  2016  16000       Manual    19834   Petrol  200  41.5
# 15181  Focus  2015   9999       Manual     7010   Diesel   20  67.3
#
#        engineSize
# 4083          1.0
# 4084          1.0
# 4089          1.0
# 4098          2.0
# 4104          1.0
# ...           ...
# 15164         1.5
# 15166         2.0
# 15168         1.0
# 15178         2.0
# 15181         1.6
#
# [4185 rows x 9 columns]

# %%
list_of_dataframes = [df3, df4, df5,df6]
dfb = pd.concat(list_of_dataframes)



dfb.boxplot(by ='model', column =["mileage"], grid = True)
# Out:
# <AxesSubplot:title={'center':'mileage'}, xlabel='model'>

# %%
sns.histplot(data=dfb, x="mileage")
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='Count'>

# %%
sns.histplot(data=dfb, x="tax")
# Out:
# <AxesSubplot:xlabel='tax', ylabel='Count'>

# %%
sns.histplot(data=dfb, x="mpg")
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Count'>

# %%
sns.histplot(data=dfb, x="engineSize")
# Out:
# <AxesSubplot:xlabel='engineSize', ylabel='Count'>

# %%
corrs = dfb.corr()
sns.heatmap(corrs)
plt.show()

# %%
sns.kdeplot(data=dfb, x="price", hue="model")
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.pairplot(dfb, hue="model")

# %%
dfb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14266 entries, 2121 to 15181
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         14266 non-null  object
#  1   year          14266 non-null  int64
#  2   price         14266 non-null  int64
#  3   transmission  14266 non-null  object
#  4   mileage       14266 non-null  int64
#  5   fuelType      14266 non-null  object
#  6   tax           14266 non-null  int64
#  7   mpg           14266 non-null  float64
#  8   engineSize    14266 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 1.6+ MB

# %%
dfb.model.unique()
# Out:
# array(['Aygo', 'Yaris', 'Fiesta', 'Focus'], dtype=object)

# %%
dfb.transmission.unique()
# Out:
# array(['Manual', 'Semi-Auto', 'Automatic', 'Other'], dtype=object)

# %%
dfb.fuelType.unique()
# Out:
# array(['Other', 'Petrol', 'Hybrid', 'Diesel'], dtype=object)

# %%
#https://towardsdatascience.com/multiple-linear-regression-model-using-python-machine-learning-d00c78f1172a
status = pd.get_dummies(dfb['model'])
status
# Out:
#        Aygo  Fiesta  Focus  Yaris
# 2121      1       0      0      0
# 2122      1       0      0      0
# 2123      1       0      0      0
# 2124      1       0      0      0
# 2125      1       0      0      0
# ...     ...     ...    ...    ...
# 15164     0       0      1      0
# 15166     0       0      1      0
# 15168     0       0      1      0
# 15178     0       0      1      0
# 15181     0       0      1      0
#
# [14266 rows x 4 columns]

# %%
status = pd.get_dummies(dfb['model'], drop_first = True)
status
# Out:
#        Fiesta  Focus  Yaris
# 2121        0      0      0
# 2122        0      0      0
# 2123        0      0      0
# 2124        0      0      0
# 2125        0      0      0
# ...       ...    ...    ...
# 15164       0      1      0
# 15166       0      1      0
# 15168       0      1      0
# 15178       0      1      0
# 15181       0      1      0
#
# [14266 rows x 3 columns]

# %%
dfc = pd.concat([dfb, status], axis = 1)

dfc.drop(['model'], axis = 1, inplace = True)

dfc
# Out:
#        year  price transmission  mileage fuelType  tax   mpg  engineSize  \
# 2121   2017   9250       Manual     4414    Other  150  68.9         1.0
# 2122   2017   7100       Manual    32351   Petrol    0  68.9         1.0
# 2123   2016   6500       Manual    26193   Petrol    0  69.0         1.0
# 2124   2017   7650       Manual    12134   Petrol    0  68.9         1.0
# 2125   2016   6999       Manual    21123   Petrol    0  69.0         1.0
# ...     ...    ...          ...      ...      ...  ...   ...         ...
# 15164  2018  14000       Manual     8724   Diesel  145  74.3         1.5
# 15166  2017  18500       Manual    10960   Petrol  145  41.5         2.0
# 15168  2017  11000       Manual    17339   Petrol  145  60.1         1.0
# 15178  2016  16000       Manual    19834   Petrol  200  41.5         2.0
# 15181  2015   9999       Manual     7010   Diesel   20  67.3         1.6
#
#        Fiesta  Focus  Yaris
# 2121        0      0      0
# 2122        0      0      0
# 2123        0      0      0
# 2124        0      0      0
# 2125        0      0      0
# ...       ...    ...    ...
# 15164       0      1      0
# 15166       0      1      0
# 15168       0      1      0
# 15178       0      1      0
# 15181       0      1      0
#
# [14266 rows x 11 columns]

# %%
statusb = pd.get_dummies(dfc['transmission'])
statusb
# Out:
#        Automatic  Manual  Other  Semi-Auto
# 2121           0       1      0          0
# 2122           0       1      0          0
# 2123           0       1      0          0
# 2124           0       1      0          0
# 2125           0       1      0          0
# ...          ...     ...    ...        ...
# 15164          0       1      0          0
# 15166          0       1      0          0
# 15168          0       1      0          0
# 15178          0       1      0          0
# 15181          0       1      0          0
#
# [14266 rows x 4 columns]

# %%
statusb = pd.get_dummies(dfc['transmission'], drop_first = True)
statusb
# Out:
#        Manual  Other  Semi-Auto
# 2121        1      0          0
# 2122        1      0          0
# 2123        1      0          0
# 2124        1      0          0
# 2125        1      0          0
# ...       ...    ...        ...
# 15164       1      0          0
# 15166       1      0          0
# 15168       1      0          0
# 15178       1      0          0
# 15181       1      0          0
#
# [14266 rows x 3 columns]

# %%
dfd = pd.concat([dfc, statusb], axis = 1)

dfd.drop(['transmission'], axis = 1, inplace = True)

dfd
# Out:
#        year  price  mileage fuelType  tax   mpg  engineSize  Fiesta  Focus  \
# 2121   2017   9250     4414    Other  150  68.9         1.0       0      0
# 2122   2017   7100    32351   Petrol    0  68.9         1.0       0      0
# 2123   2016   6500    26193   Petrol    0  69.0         1.0       0      0
# 2124   2017   7650    12134   Petrol    0  68.9         1.0       0      0
# 2125   2016   6999    21123   Petrol    0  69.0         1.0       0      0
# ...     ...    ...      ...      ...  ...   ...         ...     ...    ...
# 15164  2018  14000     8724   Diesel  145  74.3         1.5       0      1
# 15166  2017  18500    10960   Petrol  145  41.5         2.0       0      1
# 15168  2017  11000    17339   Petrol  145  60.1         1.0       0      1
# 15178  2016  16000    19834   Petrol  200  41.5         2.0       0      1
# 15181  2015   9999     7010   Diesel   20  67.3         1.6       0      1
#
#        Yaris  Manual  Other  Semi-Auto
# 2121       0       1      0          0
# 2122       0       1      0          0
# 2123       0       1      0          0
# 2124       0       1      0          0
# 2125       0       1      0          0
# ...      ...     ...    ...        ...
# 15164      0       1      0          0
# 15166      0       1      0          0
# 15168      0       1      0          0
# 15178      0       1      0          0
# 15181      0       1      0          0
#
# [14266 rows x 13 columns]

# %%
statusc = pd.get_dummies(dfd['fuelType'])
statusc
# Out:
#        Diesel  Hybrid  Other  Petrol
# 2121        0       0      1       0
# 2122        0       0      0       1
# 2123        0       0      0       1
# 2124        0       0      0       1
# 2125        0       0      0       1
# ...       ...     ...    ...     ...
# 15164       1       0      0       0
# 15166       0       0      0       1
# 15168       0       0      0       1
# 15178       0       0      0       1
# 15181       1       0      0       0
#
# [14266 rows x 4 columns]

# %%
statusc = pd.get_dummies(dfd['fuelType'], drop_first = True)
statusc
# Out:
#        Hybrid  Other  Petrol
# 2121        0      1       0
# 2122        0      0       1
# 2123        0      0       1
# 2124        0      0       1
# 2125        0      0       1
# ...       ...    ...     ...
# 15164       0      0       0
# 15166       0      0       1
# 15168       0      0       1
# 15178       0      0       1
# 15181       0      0       0
#
# [14266 rows x 3 columns]

# %%
dfe = pd.concat([dfd, statusc], axis = 1)

dfe.drop(['fuelType'], axis = 1, inplace = True)

dfe

duplicated_columns_list = []
list_of_all_columns = list(dfe.columns)
for column in list_of_all_columns:
    if list_of_all_columns.count(column) > 1 and not column in duplicated_columns_list:
        duplicated_columns_list.append(column)
duplicated_columns_list

for column in duplicated_columns_list:
    list_of_all_columns[list_of_all_columns.index(column)] = column + '_1'
    list_of_all_columns[list_of_all_columns.index(column)] = column + '_2'
dfe.columns = list_of_all_columns
dfe
# Out:
#        year  price  mileage  tax   mpg  engineSize  Fiesta  Focus  Yaris  \
# 2121   2017   9250     4414  150  68.9         1.0       0      0      0
# 2122   2017   7100    32351    0  68.9         1.0       0      0      0
# 2123   2016   6500    26193    0  69.0         1.0       0      0      0
# 2124   2017   7650    12134    0  68.9         1.0       0      0      0
# 2125   2016   6999    21123    0  69.0         1.0       0      0      0
# ...     ...    ...      ...  ...   ...         ...     ...    ...    ...
# 15164  2018  14000     8724  145  74.3         1.5       0      1      0
# 15166  2017  18500    10960  145  41.5         2.0       0      1      0
# 15168  2017  11000    17339  145  60.1         1.0       0      1      0
# 15178  2016  16000    19834  200  41.5         2.0       0      1      0
# 15181  2015   9999     7010   20  67.3         1.6       0      1      0
#
#        Manual  Other_1  Semi-Auto  Hybrid  Other_2  Petrol
# 2121        1        0          0       0        1       0
# 2122        1        0          0       0        0       1
# 2123        1        0          0       0        0       1
# 2124        1        0          0       0        0       1
# 2125        1        0          0       0        0       1
# ...       ...      ...        ...     ...      ...     ...
# 15164       1        0          0       0        0       0
# 15166       1        0          0       0        0       1
# 15168       1        0          0       0        0       1
# 15178       1        0          0       0        0       1
# 15181       1        0          0       0        0       0
#
# [14266 rows x 15 columns]

# %%
from sklearn.model_selection import train_test_split

# We specify random seed so that the train and test data set always have the same rows, respectively
np.random.seed(0)
df_train, df_test = train_test_split(dfe, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# Applying scaler() to all the columns except the 'yes-no' and 'dummy' variables
num_vars = ['year', 'price', 'mileage', 'tax', 'mpg','engineSize']
df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

df_train
# Out:
#            year     price   mileage       tax       mpg  engineSize  Fiesta  \
# 7030   0.571429  0.241423  0.125011  0.547170  0.552045    0.478261       1
# 444    0.714286  0.281863  0.240226  0.547170  0.408922    0.652174       0
# 4572   0.857143  0.434839  0.128395  0.547170  0.453532    0.434783       1
# 3001   0.428571  0.167500  0.433016  0.000000  0.641264    0.434783       0
# 14284  0.285714  0.330521  0.625652  0.075472  0.609665    0.869565       0
# ...         ...       ...       ...       ...       ...         ...     ...
# 9062   0.428571  0.467409  0.393084  0.075472  0.609665    0.869565       0
# 11329  0.571429  0.326173  0.213405  0.000000  0.579926    0.434783       1
# 14706  0.571429  0.293604  0.436213  0.547170  0.739777    0.652174       0
# 9511   0.857143  0.364917  0.068360  0.547170  0.453532    0.434783       1
# 7281   0.428571  0.260904  0.343049  0.000000  0.431227    0.434783       1
#
#        Focus  Yaris  Manual  Other_1  Semi-Auto  Hybrid  Other_2  Petrol
# 7030       0      0       1        0          0       0        0       1
# 444        0      1       1        0          0       0        0       1
# 4572       0      0       1        0          0       0        0       1
# 3001       0      0       1        0          0       0        0       1
# 14284      1      0       1        0          0       0        0       0
# ...      ...    ...     ...      ...        ...     ...      ...     ...
# 9062       1      0       1        0          0       0        0       0
# 11329      0      0       1        0          0       0        0       1
# 14706      1      0       1        0          0       0        0       0
# 9511       0      0       1        0          0       0        0       1
# 7281       0      0       0        0          1       0        0       1
#
# [9986 rows x 15 columns]

# %%
# Dividing the training data set into X and Y
y_train = df_train.pop('price')
X_train = df_train

# %%
#Build a linear model

import statsmodels.api as sm
X_train_lm = sm.add_constant(X_train)

lr_1 = sm.OLS(y_train, X_train_lm).fit()

lr_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.796
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     2771.
# Date:                Fri, 04 Feb 2022   Prob (F-statistic):               0.00
# Time:                        19:31:09   Log-Likelihood:                 12768.
# No. Observations:                9986   AIC:                        -2.551e+04
# Df Residuals:                    9971   BIC:                        -2.540e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1054      0.013     -8.065      0.000      -0.131      -0.080
# year           0.3657      0.005     72.418      0.000       0.356       0.376
# mileage       -0.1591      0.004    -36.186      0.000      -0.168      -0.150
# tax           -0.0525      0.004    -12.938      0.000      -0.060      -0.045
# mpg           -0.0879      0.008    -10.762      0.000      -0.104      -0.072
# engineSize     0.3780      0.010     38.595      0.000       0.359       0.397
# Fiesta         0.1085      0.002     47.993      0.000       0.104       0.113
# Focus          0.2036      0.003     75.478      0.000       0.198       0.209
# Yaris          0.0201      0.003      6.307      0.000       0.014       0.026
# Manual        -0.0390      0.003    -12.777      0.000      -0.045      -0.033
# Other_1        0.0688      0.068      1.019      0.308      -0.064       0.201
# Semi-Auto     -0.0160      0.004     -3.616      0.000      -0.025      -0.007
# Hybrid         0.1646      0.005     30.027      0.000       0.154       0.175
# Other_2        0.0758      0.011      6.934      0.000       0.054       0.097
# Petrol         0.0422      0.005      9.262      0.000       0.033       0.051
# ==============================================================================
# Omnibus:                     1098.987   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2624.979
# Skew:                           0.653   Prob(JB):                         0.00
# Kurtosis:                       5.145   Cond. No.                         199.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Checking for the VIF values of the variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Creating a dataframe that will contain the names of all the feature variables and their VIFs
vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#       Features    VIF
# 4   engineSize  19.24
# 0         year  19.15
# 8       Manual  17.52
# 3          mpg  14.25
# 13      Petrol   9.02
# 2          tax   7.53
# 1      mileage   6.02
# 5       Fiesta   4.48
# 6        Focus   4.02
# 7        Yaris   3.14
# 11      Hybrid   2.44
# 10   Semi-Auto   1.74
# 12     Other_2   1.09
# 9      Other_1   1.00

# %%
# Dropping highly correlated variables and insignificant variables
X = X_train.drop('Other_1', 1,)

# Build a fitted model after dropping the variable
X_train_lm = sm.add_constant(X)

lr_2 = sm.OLS(y_train, X_train_lm).fit()

# Printing the summary of the model
print(lr_2.summary())
X
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.795
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     2984.
# Date:                Fri, 04 Feb 2022   Prob (F-statistic):               0.00
# Time:                        19:31:09   Log-Likelihood:                 12768.
# No. Observations:                9986   AIC:                        -2.551e+04
# Df Residuals:                    9972   BIC:                        -2.541e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1053      0.013     -8.057      0.000      -0.131      -0.080
# year           0.3656      0.005     72.411      0.000       0.356       0.376
# mileage       -0.1591      0.004    -36.204      0.000      -0.168      -0.151
# tax           -0.0525      0.004    -12.940      0.000      -0.060      -0.045
# mpg           -0.0879      0.008    -10.767      0.000      -0.104      -0.072
# engineSize     0.3779      0.010     38.592      0.000       0.359       0.397
# Fiesta         0.1085      0.002     47.992      0.000       0.104       0.113
# Focus          0.2036      0.003     75.478      0.000       0.198       0.209
# Yaris          0.0201      0.003      6.307      0.000       0.014       0.026
# Manual        -0.0390      0.003    -12.775      0.000      -0.045      -0.033
# Semi-Auto     -0.0160      0.004     -3.617      0.000      -0.025      -0.007
# Hybrid         0.1648      0.005     30.074      0.000       0.154       0.176
# Other_2        0.0757      0.011      6.932      0.000       0.054       0.097
# Petrol         0.0422      0.005      9.258      0.000       0.033       0.051
# ==============================================================================
# Omnibus:                     1098.304   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2622.297
# Skew:                           0.653   Prob(JB):                         0.00
# Kurtosis:                       5.144   Cond. No.                         53.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#            year   mileage       tax       mpg  engineSize  Fiesta  Focus  \
# 7030   0.571429  0.125011  0.547170  0.552045    0.478261       1      0
# 444    0.714286  0.240226  0.547170  0.408922    0.652174       0      0
# 4572   0.857143  0.128395  0.547170  0.453532    0.434783       1      0
# 3001   0.428571  0.433016  0.000000  0.641264    0.434783       0      0
# 14284  0.285714  0.625652  0.075472  0.609665    0.869565       0      1
# ...         ...       ...       ...       ...         ...     ...    ...
# 9062   0.428571  0.393084  0.075472  0.609665    0.869565       0      1
# 11329  0.571429  0.213405  0.000000  0.579926    0.434783       1      0
# 14706  0.571429  0.436213  0.547170  0.739777    0.652174       0      1
# 9511   0.857143  0.068360  0.547170  0.453532    0.434783       1      0
# 7281   0.428571  0.343049  0.000000  0.431227    0.434783       1      0
#
#        Yaris  Manual  Semi-Auto  Hybrid  Other_2  Petrol
# 7030       0       1          0       0        0       1
# 444        1       1          0       0        0       1
# 4572       0       1          0       0        0       1
# 3001       0       1          0       0        0       1
# 14284      0       1          0       0        0       0
# ...      ...     ...        ...     ...      ...     ...
# 9062       0       1          0       0        0       0
# 11329      0       1          0       0        0       1
# 14706      0       1          0       0        0       0
# 9511       0       1          0       0        0       1
# 7281       0       0          1       0        0       1
#
# [9986 rows x 13 columns]

# %%
vif = pd.DataFrame()
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#       Features    VIF
# 4   engineSize  19.23
# 0         year  19.15
# 8       Manual  17.52
# 3          mpg  14.25
# 12      Petrol   9.02
# 2          tax   7.53
# 1      mileage   6.02
# 5       Fiesta   4.48
# 6        Focus   4.02
# 7        Yaris   3.14
# 10      Hybrid   2.44
# 9    Semi-Auto   1.74
# 11     Other_2   1.09

# %%
# Dropping highly correlated variables and insignificant variables
X2 = X.drop('engineSize', 1,)

# Build a fitted model after dropping the variable
X_train_lm = sm.add_constant(X2)

lr_2 = sm.OLS(y_train, X_train_lm).fit()

# Printing the summary of the model
print(lr_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.765
# Model:                            OLS   Adj. R-squared:                  0.765
# Method:                 Least Squares   F-statistic:                     2705.
# Date:                Fri, 04 Feb 2022   Prob (F-statistic):               0.00
# Time:                        19:31:10   Log-Likelihood:                 12073.
# No. Observations:                9986   AIC:                        -2.412e+04
# Df Residuals:                    9973   BIC:                        -2.403e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3113      0.008     39.415      0.000       0.296       0.327
# year           0.3183      0.005     60.617      0.000       0.308       0.329
# mileage       -0.1572      0.005    -33.368      0.000      -0.166      -0.148
# tax           -0.0248      0.004     -5.805      0.000      -0.033      -0.016
# mpg           -0.2826      0.007    -41.077      0.000      -0.296      -0.269
# Fiesta         0.0998      0.002     41.381      0.000       0.095       0.105
# Focus          0.1975      0.003     68.422      0.000       0.192       0.203
# Yaris          0.0488      0.003     14.732      0.000       0.042       0.055
# Manual        -0.0290      0.003     -8.899      0.000      -0.035      -0.023
# Semi-Auto     -0.0237      0.005     -5.004      0.000      -0.033      -0.014
# Hybrid         0.1445      0.006     24.712      0.000       0.133       0.156
# Other_2       -0.0357      0.011     -3.161      0.002      -0.058      -0.014
# Petrol        -0.0902      0.003    -28.095      0.000      -0.097      -0.084
# ==============================================================================
# Omnibus:                     1250.433   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3080.943
# Skew:                           0.723   Prob(JB):                         0.00
# Kurtosis:                       5.305   Cond. No.                         32.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
vif = pd.DataFrame()
vif['Features'] = X2.columns
vif['VIF'] = [variance_inflation_factor(X2.values, i) for i in range(X2.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#      Features    VIF
# 0        year  18.74
# 7      Manual  16.51
# 3         mpg  13.94
# 11     Petrol   8.90
# 2         tax   7.16
# 1     mileage   5.47
# 4      Fiesta   4.12
# 5       Focus   3.19
# 9      Hybrid   2.42
# 6       Yaris   2.39
# 8   Semi-Auto   1.65
# 10    Other_2   1.08

# %%
# Dropping highly correlated variables and insignificant variables
X3 = X2.drop('Manual', 1,)

# Build a fitted model after dropping the variable
X_train_lm = sm.add_constant(X3)

lr_2 = sm.OLS(y_train, X_train_lm).fit()

# Printing the summary of the model
print(lr_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                     2920.
# Date:                Fri, 04 Feb 2022   Prob (F-statistic):               0.00
# Time:                        19:31:10   Log-Likelihood:                 12033.
# No. Observations:                9986   AIC:                        -2.404e+04
# Df Residuals:                    9974   BIC:                        -2.396e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2949      0.008     38.248      0.000       0.280       0.310
# year           0.3172      0.005     60.185      0.000       0.307       0.328
# mileage       -0.1601      0.005    -33.934      0.000      -0.169      -0.151
# tax           -0.0251      0.004     -5.847      0.000      -0.034      -0.017
# mpg           -0.2930      0.007    -43.041      0.000      -0.306      -0.280
# Fiesta         0.0989      0.002     40.876      0.000       0.094       0.104
# Focus          0.1973      0.003     68.068      0.000       0.192       0.203
# Yaris          0.0496      0.003     14.904      0.000       0.043       0.056
# Semi-Auto      0.0027      0.004      0.738      0.460      -0.005       0.010
# Hybrid         0.1702      0.005     33.324      0.000       0.160       0.180
# Other_2       -0.0134      0.011     -1.215      0.224      -0.035       0.008
# Petrol        -0.0944      0.003    -29.599      0.000      -0.101      -0.088
# ==============================================================================
# Omnibus:                     1147.585   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2657.895
# Skew:                           0.688   Prob(JB):                         0.00
# Kurtosis:                       5.120   Cond. No.                         28.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
vif = pd.DataFrame()
vif['Features'] = X3.columns
vif['VIF'] = [variance_inflation_factor(X3.values, i) for i in range(X3.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#      Features    VIF
# 0        year  18.50
# 3         mpg  11.10
# 10     Petrol   7.28
# 2         tax   7.15
# 1     mileage   5.32
# 4      Fiesta   4.02
# 5       Focus   3.10
# 6       Yaris   2.37
# 8      Hybrid   1.88
# 7   Semi-Auto   1.06
# 9     Other_2   1.05

# %%
# Dropping highly correlated variables and insignificant variables
X4 = X3.drop('Semi-Auto', 1,)

# Build a fitted model after dropping the variable
X_train_lm = sm.add_constant(X4)

lr_2 = sm.OLS(y_train, X_train_lm).fit()

# Printing the summary of the model
print(lr_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                     3212.
# Date:                Fri, 04 Feb 2022   Prob (F-statistic):               0.00
# Time:                        19:31:10   Log-Likelihood:                 12033.
# No. Observations:                9986   AIC:                        -2.404e+04
# Df Residuals:                    9975   BIC:                        -2.396e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2960      0.008     39.197      0.000       0.281       0.311
# year           0.3170      0.005     60.244      0.000       0.307       0.327
# mileage       -0.1602      0.005    -33.984      0.000      -0.169      -0.151
# tax           -0.0252      0.004     -5.856      0.000      -0.034      -0.017
# mpg           -0.2939      0.007    -43.899      0.000      -0.307      -0.281
# Fiesta         0.0987      0.002     41.001      0.000       0.094       0.103
# Focus          0.1970      0.003     68.541      0.000       0.191       0.203
# Yaris          0.0492      0.003     14.961      0.000       0.043       0.056
# Hybrid         0.1703      0.005     33.377      0.000       0.160       0.180
# Other_2       -0.0138      0.011     -1.250      0.211      -0.035       0.008
# Petrol        -0.0946      0.003    -29.793      0.000      -0.101      -0.088
# ==============================================================================
# Omnibus:                     1141.474   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2634.054
# Skew:                           0.686   Prob(JB):                         0.00
# Kurtosis:                       5.109   Cond. No.                         27.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
vif = pd.DataFrame()
vif['Features'] = X4.columns
vif['VIF'] = [variance_inflation_factor(X4.values, i) for i in range(X4.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#   Features    VIF
# 0     year  18.50
# 3      mpg  11.08
# 9   Petrol   7.23
# 2      tax   7.15
# 1  mileage   5.31
# 4   Fiesta   4.02
# 5    Focus   3.10
# 6    Yaris   2.36
# 7   Hybrid   1.87
# 8  Other_2   1.05

# %%
# Dropping highly correlated variables and insignificant variables
X5 = X4.drop('Other_2', 1,)

# Build a fitted model after dropping the variable
X_train_lm = sm.add_constant(X5)

lr_2 = sm.OLS(y_train, X_train_lm).fit()

# Printing the summary of the model
print(lr_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                     3569.
# Date:                Fri, 04 Feb 2022   Prob (F-statistic):               0.00
# Time:                        19:31:10   Log-Likelihood:                 12032.
# No. Observations:                9986   AIC:                        -2.404e+04
# Df Residuals:                    9976   BIC:                        -2.397e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2938      0.007     40.067      0.000       0.279       0.308
# year           0.3171      0.005     60.295      0.000       0.307       0.327
# mileage       -0.1600      0.005    -33.960      0.000      -0.169      -0.151
# tax           -0.0252      0.004     -5.861      0.000      -0.034      -0.017
# mpg           -0.2928      0.007    -44.106      0.000      -0.306      -0.280
# Fiesta         0.0992      0.002     41.940      0.000       0.095       0.104
# Focus          0.1979      0.003     70.928      0.000       0.192       0.203
# Yaris          0.0498      0.003     15.280      0.000       0.043       0.056
# Hybrid         0.1709      0.005     33.659      0.000       0.161       0.181
# Petrol        -0.0936      0.003    -30.572      0.000      -0.100      -0.088
# ==============================================================================
# Omnibus:                     1144.346   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2640.789
# Skew:                           0.688   Prob(JB):                         0.00
# Kurtosis:                       5.111   Cond. No.                         23.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
vif = pd.DataFrame()
vif['Features'] = X5.columns
vif['VIF'] = [variance_inflation_factor(X5.values, i) for i in range(X5.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#   Features    VIF
# 0     year  18.42
# 3      mpg  11.02
# 2      tax   7.13
# 8   Petrol   7.09
# 1  mileage   5.29
# 4   Fiesta   3.99
# 5    Focus   3.04
# 6    Yaris   2.36
# 7   Hybrid   1.86

# %%
# Dropping highly correlated variables and insignificant variables
X6 = X5.drop('year', 1,)

# Build a fitted model after dropping the variable
X_train_lm = sm.add_constant(X6)

lr_2 = sm.OLS(y_train, X_train_lm).fit()

# Printing the summary of the model
print(lr_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.677
# Model:                            OLS   Adj. R-squared:                  0.676
# Method:                 Least Squares   F-statistic:                     2610.
# Date:                Fri, 04 Feb 2022   Prob (F-statistic):               0.00
# Time:                        19:31:10   Log-Likelihood:                 10481.
# No. Observations:                9986   AIC:                        -2.094e+04
# Df Residuals:                    9977   BIC:                        -2.088e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4510      0.008     56.353      0.000       0.435       0.467
# mileage       -0.3186      0.005    -69.785      0.000      -0.328      -0.310
# tax            0.1106      0.004     25.874      0.000       0.102       0.119
# mpg           -0.2338      0.008    -30.479      0.000      -0.249      -0.219
# Fiesta         0.0989      0.003     35.793      0.000       0.093       0.104
# Focus          0.2065      0.003     63.463      0.000       0.200       0.213
# Yaris          0.0623      0.004     16.406      0.000       0.055       0.070
# Hybrid         0.1440      0.006     24.365      0.000       0.132       0.156
# Petrol        -0.0975      0.004    -27.287      0.000      -0.105      -0.091
# ==============================================================================
# Omnibus:                      473.369   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              931.497
# Skew:                           0.347   Prob(JB):                    5.35e-203
# Kurtosis:                       4.325   Cond. No.                         21.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
vif = pd.DataFrame()
vif['Features'] = X6.columns
vif['VIF'] = [variance_inflation_factor(X6.values, i) for i in range(X6.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#   Features   VIF
# 2      mpg  6.60
# 7   Petrol  6.15
# 1      tax  4.31
# 0  mileage  4.03
# 3   Fiesta  3.89
# 4    Focus  2.76
# 5    Yaris  2.21
# 6   Hybrid  1.85

# %%
import seaborn as sns
y_train_price = lr_2.predict(X_train_lm)
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_price), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading 
plt.xlabel('Errors', fontsize = 18)                         # X-label
# Out:
# Text(0.5, 0, 'Errors')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

num_vars = ['year', 'price', 'mileage', 'tax', 'mpg','engineSize']
df_test[num_vars] = scaler.fit_transform(df_test[num_vars])

df_test
# Out:
#            year     price   mileage       tax       mpg  engineSize  Fiesta  \
# 7817   0.857143  0.633158  0.104965  0.604167  0.453532    0.434783       0
# 13328  0.857143  0.525088  0.149315  0.625000  0.858736    0.652174       0
# 10003  0.857143  0.676916  0.018118  0.604167  0.280669    0.434783       0
# 7379   0.571429  0.370311  0.283293  0.520833  0.314126    0.434783       0
# 2930   0.428571  0.108591  0.351182  0.000000  0.641264    0.434783       0
# ...         ...       ...       ...       ...       ...         ...     ...
# 6922   0.714286  0.349495  0.133102  0.604167  0.453532    0.434783       1
# 2369   0.714286  0.199879  0.204955  0.604167  0.639405    0.434783       0
# 11363  0.571429  0.286179  0.192156  0.000000  0.579926    0.434783       1
# 11388  0.714286  0.329546  0.409721  0.604167  0.579926    0.434783       1
# 13261  0.714286  0.429680  0.241550  0.604167  0.431227    0.434783       0
#
#        Focus  Yaris  Manual  Other_1  Semi-Auto  Hybrid  Other_2  Petrol
# 7817       1      0       1        0          0       0        0       1
# 13328      1      0       1        0          0       0        0       0
# 10003      1      0       1        0          0       0        0       1
# 7379       1      0       0        0          1       0        0       1
# 2930       0      0       1        0          0       0        0       1
# ...      ...    ...     ...      ...        ...     ...      ...     ...
# 6922       0      0       1        0          0       0        0       1
# 2369       0      0       1        0          0       0        0       1
# 11363      0      0       1        0          0       0        0       1
# 11388      0      0       1        0          0       0        0       1
# 13261      1      0       1        0          0       0        0       1
#
# [4280 rows x 15 columns]

# %%
y_test = df_test.pop('price')
X_test = df_test

# Adding constant variable to test dataframe
X_test_m4 = sm.add_constant(X_test)

# Creating X_test_m4 dataframe by dropping variables from X_test_m4
X_test_m4 = X_test_m4.drop(["Other_1", "engineSize", "Manual","Semi-Auto","Other_2","year"], axis = 1)

# Making predictions using the final model
y_pred_m4 = lr_2.predict(X_test_m4)

# %%
from sklearn.metrics import r2_score
r2_score(y_true = y_test, y_pred = y_pred_m4)
# Out:
# 0.698068323723005

# %%
# Multiple Regression Equation

# y'(price) = .45 + (-.32)mileage + (.11)tax + (-.23)mpg + (.10)Fiesta + (.21)Focus + (.06)Yaris + (.14)Hybrid + (-.10)Petrol

.45 + (-.32)*20000 + (.11)*150 + (-.23)*50 + (.10)*1 + (.21)*0 + (.06)*0 + (.14)*0 + (-.10)*0
# Out:
# -6394.45

# %%
#conclusion >> mpg should be removed since it doesn't follow a normal distribution
